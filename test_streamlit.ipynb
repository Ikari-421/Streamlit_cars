# %%
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


st.title('Hello Wilders, welcome to my application!')

link = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/cars.csv"
df_cars = pd.read_csv(link)

# %%
df_cars['continent'].unique()
# Out:
# array([' US.', ' Europe.', ' Japan.'], dtype=object)

# %%
options = ['US.', 'Europe.', 'Japan.']
df_filtered = df_cars[df_cars['continent'].isin(options)]
df_filtered
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, cubicinches, hp, weightlbs, time-to-60, year, continent]
# Index: []

# %%
df_cars.head()
# Out:
#     mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0  14.0          8          350  165       4209          12  1972       US.
# 1  31.9          4           89   71       1925          14  1980   Europe.
# 2  17.0          8          302  140       3449          11  1971       US.
# 3  15.0          8          400  150       3761          10  1971       US.
# 4  30.5          4           98   63       2051          17  1978       US.

# %%
df_cars.describe(include="all").round(2)
# Out:
#            mpg  cylinders  cubicinches      hp  weightlbs  time-to-60  \
# count   261.00     261.00       261.00  261.00     261.00      261.00
# unique     NaN        NaN          NaN     NaN        NaN         NaN
# top        NaN        NaN          NaN     NaN        NaN         NaN
# freq       NaN        NaN          NaN     NaN        NaN         NaN
# mean     23.14       5.59       200.88  106.36    3009.38       15.55
# std       7.82       1.73       108.84   40.50     849.12        2.91
# min      10.00       3.00        68.00   46.00    1613.00        8.00
# 25%      16.90       4.00       101.00   75.00    2254.00       14.00
# 50%      22.00       6.00       156.00   95.00    2900.00       16.00
# 75%      28.80       8.00       302.00  138.00    3664.00       17.00
# max      46.60       8.00       455.00  230.00    4997.00       25.00
#
#            year continent
# count    261.00       261
# unique      NaN         3
# top         NaN       US.
# freq        NaN       162
# mean    1976.82       NaN
# std        3.64       NaN
# min     1971.00       NaN
# 25%     1974.00       NaN
# 50%     1977.00       NaN
# 75%     1980.00       NaN
# max     1983.00       NaN

# %%
df_cars["continent_id"] = pd.factorize(df_cars["continent"])[0]
df_cars_to_corr = df_cars[["mpg", "cylinders", "cubicinches", "hp", "weightlbs", "time-to-60", "year"]]
viz_correlation = sns.heatmap(df_cars_to_corr.corr(), 
								center=0,
								cmap = sns.color_palette("vlag", as_cmap=True)
								)
plt.xticks(rotation=45)


st.pyplot(viz_correlation.figure)
plt.show()
# Out:
# DeltaGenerator()

# %%
sns.pairplot(df_cars, hue="continent")
plt.show()

# %%
for columns in df_cars:
        # print(columns)
        fig, ax = plt.subplots(figsize = (8,2))
        sns.boxplot(data=df_cars, x =columns)
        plt.show()

# %%
sns.histplot(
    df_cars, x="cylinders"
)
plt.show()

# %%
# print(np.version)
print(sns.__version__)
print(pd.__version__)
print(st.__version__)
# Out:
# 0.13.2
# 2.2.0
# 1.30.0
